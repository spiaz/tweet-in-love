# %%
# %run 00.style.ipynb
# Out:
# /Users/piazza/Playground/tweet-in-love

# %%
import spacy
from spacy.language import Language

from tweet_in_love.settings import GlobalSettings, ModelSettings

# %%
tag = "web_sm"
version = 1

settings = GlobalSettings(tag=tag)
model_settings = ModelSettings(tag=tag, version=version)

# %%
model_settings.model_best
# Out:
# PosixPath('models/model_web_sm_01/model-best')

# %%
nlp = spacy.load(model_settings.model_best)

# %%
docs = list(
    nlp.pipe(
        [
            "I'm glad you are here!!",
            "wtf is this?",
            "not boring at all!",
            "Today I'm :)",
        ]
    )
)

# %%
for doc in docs:
    d = doc.cats
    pd.DataFrame({"score": d}).sort_values(by="score").plot.barh()
    plt.title(doc)
    best = max(d, key=d.get)
    plt.xlabel(f"best prediction: {best}")
